# %%
! pip install pandas requests python-dotenv openpyxl xlrd jupyterlab
# Out:
# Requirement already satisfied: pandas in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: requests in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (2.34.0)
# Requirement already satisfied: python-dotenv in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: openpyxl in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (3.1.5)
# Requirement already satisfied: xlrd in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (2.0.2)
# Requirement already satisfied: jupyterlab in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (4.5.7)
# Requirement already satisfied: numpy>=1.22.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from requests) (3.14)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from requests) (2026.4.22)
# Requirement already satisfied: et-xmlfile in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (7.2.0)
# Requirement already satisfied: jinja2>=3.0.3 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (26.2)
# Requirement already satisfied: setuptools>=41.1.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (79.0.1)
# Requirement already satisfied: tomli>=1.2.2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (2.4.1)
# Requirement already satisfied: tornado>=6.2.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (6.5.5)
# Requirement already satisfied: traitlets in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab) (5.15.0)
# Requirement already satisfied: anyio in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (4.13.0)
# Requirement already satisfied: httpcore==1.* in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.25.0)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (3.0.3)
# Requirement already satisfied: pyzmq>=24 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.9.0)
# Requirement already satisfied: babel>=2.10 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.26.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (8.39.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.2.2)
# Requirement already satisfied: colorama in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.4.6)
# Requirement already satisfied: decorator in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.20.0)
# Requirement already satisfied: stack_data in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: wcwidth in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-core->jupyterlab) (4.9.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.3)
# Requirement already satisfied: rfc3339-validator in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.3.0)
# Requirement already satisfied: defusedxml in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.2)
# Requirement already satisfied: six>=1.5 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.0.0)
# Requirement already satisfied: pycparser in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: executing>=1.2.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.1)
# Requirement already satisfied: pure-eval in d:\fir document\universitas negeri surabaya\semester 4\data warehouse\task\final_project\dwh-energy-project\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.3)

# %%
import pandas as pd
import os

STAGING_DIR = "../data/staging/"

# Load semua file
eia_gen    = pd.read_csv(f"{STAGING_DIR}eia_generation_2022_2024.csv")
eia_retail = pd.read_csv(f"{STAGING_DIR}eia_retail_2022_2024.csv")
wb_cpi     = pd.read_csv(f"{STAGING_DIR}wb_cpi_2022_2024.csv")
wb_gdp     = pd.read_csv(f"{STAGING_DIR}wb_gdp_2022_2024.csv")
wb_ind     = pd.read_csv(f"{STAGING_DIR}wb_industrial_2022_2024.csv")
wb_unemp   = pd.read_csv(f"{STAGING_DIR}wb_unemployment_2022_2024.csv")
wb_fx      = pd.read_csv(f"{STAGING_DIR}wb_exchange_rate_2022_2024.csv")

print("Semua file berhasil di-load ✓")
# Out:
# Semua file berhasil di-load ✓

# %%
datasets = {
    "eia_generation" : eia_gen,
    "eia_retail"     : eia_retail,
    "wb_cpi"         : wb_cpi,
    "wb_gdp"         : wb_gdp,
    "wb_industrial"  : wb_ind,
    "wb_unemployment": wb_unemp,
    "wb_exchange_rate": wb_fx,
}

for name, df in datasets.items():
    print(f"\n{'='*50}")
    print(f"📄 {name}")
    print(f"   Shape  : {df.shape}")
    print(f"   Kolom  : {df.columns.tolist()}")
    print(f"   Sample :")
    print(df.head(3).to_string())
# Out:
# ==================================================
# 📄 eia_generation
#    Shape  : (3324, 9)
#    Kolom  : ['period', 'location', 'stateDescription', 'sectorid', 'sectorDescription', 'fueltypeid', 'fuelTypeDescription', 'generation', 'generation-units']
#    Sample :
#     period location stateDescription  sectorid sectorDescription fueltypeid         fuelTypeDescription   generation        generation-units
# 0  2022-01       US       U.S. Total         1  Electric Utility        COL  coal, excluding waste coal  63817.58413  thousand megawatthours
# 1  2022-01       US       U.S. Total         1  Electric Utility        GEO                  geothermal     95.99719  thousand megawatthours
# 2  2022-01       US       U.S. Total         1  Electric Utility        HYC  conventional hydroelectric  22394.80501  thousand megawatthours
#
# ==================================================
# 📄 eia_retail
#    Shape  : (144, 11)
#    Kolom  : ['period', 'stateid', 'stateDescription', 'sectorid', 'sectorName', 'sales', 'price', 'revenue', 'sales-units', 'price-units', 'revenue-units']
#    Sample :
#     period stateid stateDescription sectorid   sectorName         sales  price      revenue             sales-units              price-units    revenue-units
# 0  2022-01      US       U.S. Total      ALL  all sectors  338656.04633  11.24  38053.17761  million kilowatt hours  cents per kilowatt-hour  million dollars
# 1  2022-01      US       U.S. Total      COM   commercial  113605.09055  11.26  12793.64264  million kilowatt hours  cents per kilowatt-hour  million dollars
# 2  2022-01      US       U.S. Total      IND   industrial   83982.00591   7.19   6037.27387  million kilowatt hours  cents per kilowatt-hour  million dollars
#
# ==================================================
# 📄 wb_cpi
#    Shape  : (288, 3)
#    Kolom  : ['period_raw', 'country', 'cpi_pct_yoy']
#    Sample :
#   period_raw        country  cpi_pct_yoy
# 0    2022M01  United States     7.558806
# 1    2022M02  United States     7.937279
# 2    2022M03  United States     8.572205
#
# ==================================================
# 📄 wb_gdp
#    Shape  : (288, 3)
#    Kolom  : ['period_raw', 'country', 'gdp_current_usd_mn']
#    Sample :
#   period_raw        country  gdp_current_usd_mn
# 0    2022M01  United States          26054600.0
# 1    2022M02  United States          26054600.0
# 2    2022M03  United States          26054600.0
#
# ==================================================
# 📄 wb_industrial
#    Shape  : (288, 3)
#    Kolom  : ['period_raw', 'country', 'industrial_prod_usd']
#    Sample :
#   period_raw        country  industrial_prod_usd
# 0    2022M01  United States         2.720000e+11
# 1    2022M02  United States         2.730000e+11
# 2    2022M03  United States         2.750000e+11
#
# ==================================================
# 📄 wb_unemployment
#    Shape  : (216, 3)
#    Kolom  : ['period_raw', 'country', 'unemployment_rate']
#    Sample :
#   period_raw        country  unemployment_rate
# 0    2022M01  United States                4.0
# 1    2022M02  United States                3.9
# 2    2022M03  United States                3.7
#
# ==================================================
# 📄 wb_exchange_rate
#    Shape  : (288, 3)
#    Kolom  : ['period_raw', 'country', 'exchange_rate_lcu_usd']
#    Sample :
#   period_raw        country  exchange_rate_lcu_usd
# 0    2022M01  United States                    1.0
# 1    2022M02  United States                    1.0
# 2    2022M03  United States                    1.0
